# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn
matplotlib.style.use('ggplot')
from scipy.stats import ttest_ind
from scipy.stats import chi2_contingency
from sklearn.cluster import KMeans

# %% [markdown]
# ### Load data and understand data types

# %%
data = pd.read_csv('D:/datasets/odi-batting.csv')
data.dtypes
# Out:
# Country       object
# Player        object
# Runs         float64
# ScoreRate    float64
# MatchDate     object
# Weekday       object
# Ground        object
# Versus        object
# URL           object
# dtype: object

# %% [markdown]
# ### Look at your data

# %%
data.head()
# Out:
#        Country            Player   Runs  ScoreRate   MatchDate Weekday  \
# 0  Afghanistan  Mohammad Shahzad  118.0      97.52  16-02-2010     Tue
# 1  Afghanistan  Mohammad Shahzad  110.0      99.09  01-09-2009     Tue
# 2  Afghanistan  Mohammad Shahzad  100.0     138.88  16-08-2010     Mon
# 3  Afghanistan  Mohammad Shahzad   82.0      75.92  10-07-2010     Sat
# 4  Afghanistan  Mohammad Shahzad   57.0     100.00  01-07-2010     Thu
#
#                   Ground       Versus  \
# 0     Sharjah CA Stadium       Canada
# 1             VRA Ground  Netherlands
# 2  Cambusdoon New Ground     Scotland
# 3            Hazelaarweg  Netherlands
# 4    Sportpark Westvliet       Canada
#
#                                                 URL
# 0  ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# 1  ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# 2  ../Matches/MatchScorecard_ODI.asp?MatchCode=3164
# 3  ../Matches/MatchScorecard_ODI.asp?MatchCode=3153
# 4  ../Matches/MatchScorecard_ODI.asp?MatchCode=3135

# %% [markdown]
# ### Summary Statistics
# This is the first step in any machine learning excercise

# %%
data.describe(include='all')
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Country              Player          Runs     ScoreRate   MatchDate  \
# count    55926               55926  55900.000000  55900.000000       55926
# unique      22                1936           NaN           NaN        2757
# top      India  Sachin R Tendulkar           NaN           NaN  04-02-2007
# freq      6634                 442           NaN           NaN         108
# mean       NaN                 NaN     22.241413     65.314208         NaN
# std        NaN                 NaN     25.558363     44.213423         NaN
# min        NaN                 NaN      0.000000      0.000000         NaN
# 25%        NaN                 NaN           NaN           NaN         NaN
# 50%        NaN                 NaN           NaN           NaN         NaN
# 75%        NaN                 NaN           NaN           NaN         NaN
# max        NaN                 NaN    200.000000    600.000000         NaN
#
#        Weekday              Ground     Versus  \
# count    55926               55926      55926
# unique       7                 178         25
# top        Sun  Sharjah CA Stadium  Australia
# freq     11427                3581       7216
# mean       NaN                 NaN        NaN
# std        NaN                 NaN        NaN
# min        NaN                 NaN        NaN
# 25%        NaN                 NaN        NaN
# 50%        NaN                 NaN        NaN
# 75%        NaN                 NaN        NaN
# max        NaN                 NaN        NaN
#
#                                                      URL
# count                                              55926
# unique                                              3209
# top     ../Matches/MatchScorecard_ODI.asp?MatchCode=1208
# freq                                                  22
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN

# %% [markdown]
# ### Frequency Distribution of Dimensions
# #### Count by Players

# %%
data.Player.value_counts().head(15)[::-1].plot.barh(figsize=(20,7))

# %% [markdown]
# #### Count by Country

# %%
data.Country.value_counts().head(15)[::-1].plot.barh(figsize=(20,7))

# %% [markdown]
# #### Count by Ground

# %%
data.Ground.value_counts().head(15)[::-1].plot.barh(figsize=(20,7))

# %% [markdown]
# #### Count by Versus

# %%
data.Versus.value_counts().head(15)[::-1].plot.barh(figsize=(20,7))

# %% [markdown]
# ### Frequency distribution of metrics

# %%
data[['Runs', 'ScoreRate']].plot.hist(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DD72CF8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DF246A0>], dtype=object)

# %% [markdown]
# ### Derive Metrics
# #### Metrics from Dates

# %%
data['MatchDate'] = pd.to_datetime(data['MatchDate'])
data['MatchDate'].head()
# Out:
# 0   2010-02-16
# 1   2009-01-09
# 2   2010-08-16
# 3   2010-10-07
# 4   2010-01-07
# Name: MatchDate, dtype: datetime64[ns]

# %%
data['DayofWeek'] = data.MatchDate.dt.strftime('%A')
data['Month'] = data.MatchDate.dt.strftime('%m')
data['Day'] = data.MatchDate.dt.day
data['Year'] = data.MatchDate.dt.year
dates_cols = ['DayofWeek', 'Month', 'Day', 'Year']
data[dates_cols].head()
# Out:
#   DayofWeek Month  Day  Year
# 0   Tuesday    02   16  2010
# 1    Friday    01    9  2009
# 2    Monday    08   16  2010
# 3  Thursday    10    7  2010
# 4  Thursday    01    7  2010

# %%
fig, axs = plt.subplots(2, 2)
data.Year.value_counts().sort_index().plot.bar(ax=axs[0,0], figsize=(20,10))
data.Month.value_counts().sort_index().plot.bar(ax=axs[0,1])
data.DayofWeek.value_counts().plot.bar(ax=axs[1,0])
data.Day.value_counts().sort_index().plot.bar(ax=axs[1,1])

# %%
plot_data = data['Year'].value_counts().sort_index()
my_colors = np.array(['#1F77B4'] * len(plot_data))
plot_data.plot(kind='bar', figsize=(20, 7), color=my_colors)

# %%
plot_data = data['Year'].value_counts().sort_index()
my_colors = np.array(['#1F77B4'] * len(plot_data))
my_colors[[4, 8, 12, 16, 21, 25, 28, 32, 36]] = '#E24A33'
plot_data.plot(kind='bar', figsize=(20, 5), color=my_colors)

# %% [markdown]
# #### Metrics from Text

# %%
data['names_words'] = data['Player'].str.split(' ').apply(lambda v: len(v))
data['names_first_char'] = data['Player'].str[0]
data['names_last_char'] = data['Player'].str[-1]
data['names_chars'] = data['Player'].str.len() 
data[['names_words', 'names_first_char', 'names_chars', 'names_last_char']].head()
# Out:
#    names_words names_first_char  names_chars names_last_char
# 0            2                M           16               d
# 1            2                M           16               d
# 2            2                M           16               d
# 3            2                M           16               d
# 4            2                M           16               d

# %%
fig, axs = plt.subplots(2, 2)
data.groupby('Player')['names_words'].first().sort_values(ascending=False).head(10)[::-1].plot.barh(ax=axs[0,0], figsize=(20,10))
data.groupby('Player')['names_chars'].first().sort_values(ascending=False).head(10)[::-1].plot.barh(ax=axs[0,1])
first_char = data.groupby(['Player', 'names_first_char'])['Country'].first().reset_index()['names_first_char'].value_counts().head(26)
first_char.sort_index().plot.bar(ax=axs[1,0])
last_char = data.groupby(['Player', 'names_last_char'])['Country'].first().reset_index()['names_last_char'].value_counts().head(26)
last_char.sort_index().plot.bar(ax=axs[1,1])

# %% [markdown]
# ### Bi-variate Analysis

# %%
crosstab = pd.crosstab(index=data['DayofWeek'], columns=data['Month'], values=data['Runs'], aggfunc='mean')
seaborn.heatmap(crosstab)

# %%
crosstab = pd.crosstab(index=data['Country'], columns=data['Versus'], values=data['Runs'], aggfunc='mean')
seaborn.heatmap(crosstab)

# %% [markdown]
# ### Statistical Validation

# %%
weekly = data.groupby(['Weekday'])['ScoreRate'].mean().sort_values(ascending=False)
weekly.plot.bar()

# %% [markdown]
# #### Hypothesis test

# %%
samples_hi_mean = data[data['Weekday'] == 'Tue']['ScoreRate'].dropna()
samples_lo_mean = data[data['Weekday'] == 'Wed']['ScoreRate'].dropna()

t, p = ttest_ind(samples_hi_mean.values, samples_lo_mean.values)
print t, p
if p > 0.01:
    print 'Means are not independent'
else:
    print 'Mean are independent'
# Out:
# 4.33454783623 1.46959502667e-05
# Mean are independent

# %% [markdown]
# ### Machine learning
# #### K-Means Clustering

# %%
data._get_numeric_data().head()
# Out:
#     Runs  ScoreRate  Day  Year  names_words  names_chars
# 0  118.0      97.52   16  2010            2           16
# 1  110.0      99.09    9  2009            2           16
# 2  100.0     138.88   16  2010            2           16
# 3   82.0      75.92    7  2010            2           16
# 4   57.0     100.00    7  2010            2           16

# %%
kmeans = KMeans(n_clusters=10)
players = data[['Player', 'ScoreRate', 'Runs', 'names_words', 'names_chars']].groupby('Player').mean()
fit = kmeans.fit(players)
players['cluster'] = fit.labels_
players = players.reset_index()

# %%
players.head()
# Out:
#          Player  ScoreRate       Runs  names_words  names_chars  cluster
# 0   Aamer Hanif  70.295000  22.250000            2           11        1
# 1   Aamer Malik  50.136957  24.173913            2           11        8
# 2   Aamir Nazir  85.416667   4.333333            2           11        2
# 3  Aamir Sohail  57.796710  30.838710            2           12        8
# 4   Aaqib Javed  64.442549   5.235294            2           11        6

# %%
players.cluster.value_counts()
# Out:
# 6    338
# 0    297
# 8    277
# 1    276
# 5    246
# 2    216
# 3    137
# 9    124
# 4     24
# 7      1
# Name: cluster, dtype: int64

# %%
players[players['cluster'] == 0]['Player'].unique()
# Out:
# array(['Aashish R Kapoor', 'Aasif Y Karim', 'Abdur Rehman',
#        'Abhijit V Kale', 'Aijaz Ali', 'Ajith P Weerakkody',
#        'Al Sahariar Rokon', 'Alam Talukdar', 'Alan C I Lock',
#        'Alan G Hurst', 'Alan P Igglesden', 'Alester Maregwede',
#        'Alfred S Luseno', 'Ali Asad', 'Andrew D Poynter',
#        'Andrew J Pycroft', 'Anthony McGrath', 'Anthony O Suji',
#        'Antony R M Opatha', 'Arachchige W R Madurasinghe', 'Arshad Ali',
#        'Arshad Laeeq', 'Arthur D J Pitcher', 'Ashraf Ali', 'Asif Masood',
#        'Ata-Ur-Rehman', 'Athanasios J Traicos', 'Austin Codrington',
#        'Azeem Hafeez', 'Balfour P Patterson', 'Balwinder S Sandhu',
#        'Benjamin A Stokes', 'Benjamin W Hilfenhaus', 'Bernard D Julien',
#        'Bharat Reddy', 'Bhupinder Singh', 'Bishen S Bedi', 'Brett Geeves',
#        'Bruce A Reid', 'Bruce N French', 'Bruce Yardley',
#        'Bryan G Murgatroyd', 'Calum S Macleod', 'Charles A Reid',
#        'Christopher E W Silverwood', 'Christopher T Tremlett',
#        'Clifton J Richards', 'Clinton J McKay', 'Colin E H Croft',
#        'Colin M Wells', 'Conganige R D Fernando', 'Corey D Collymore',
#        'Cornelius C Henry', 'Craig D Cumming', 'Daniel K Morrison',
#        'Daniel R Flynn', 'Daren B Powell', 'Darryl Brown',
#        'David A Murray', 'David J White', 'David R Gilbert',
#        "David R O'Sullivan", 'David T Mutendera', 'David Williams',
#        'Davis Joseph', 'Dayle R Hadlee', 'Dean W Headley', 'Deep Dasgupta',
#        'Delyone C Borden', 'Derek L Underwood', 'Devon C Thomas',
#        'Dhiman Ghosh', 'Dinanath Ramnarine', 'Dirk P Nannes',
#        'Dirk P Viljoen', 'Doddanarasiah Ganesh', 'Dominic S Wesonga',
#        'Donald J Pringle', 'Douglas T Hondo', 'Dudley M Vonhagt',
#        'Durand Soraine', 'E H Shadeep N Silva', 'Edward C Rainsford',
#        'Edward E Hemmings', 'Edward O Odumbe', 'Ehsanul Haque',
#        'Eknath D Solkar', 'Enamul Haque Jr', 'Errol L R Stewart',
#        'Evan J Gray', 'Ezra A Moseley', 'Faisal Hossain',
#        'Fidel H Edwards', 'Floyd L Reifer', 'Gareth J Batty',
#        'Gary C Martin', 'Gavin A Briant', 'Geert-Maarten C Mol',
#        'Geoffrey Dymock', 'Geoffrey G Arnold', 'Geoffrey Miller',
#        'Geoffrey W Humpage', 'George Salmond', 'Gholam Nousher',
#        'Ginigalgodage R A de Silva', 'Gladstone C Small', 'Glenn A Rogers',
#        'Glenn D McGrath', 'Golam Faruq', 'Gordon Goudie',
#        'Graham E Vivian', 'Graham Onions', 'Grant E Bradburn',
#        'Granville N De Silva', 'Gregory M Strydom', 'Gursharan Singh',
#        'H A Prasanna W Jayawardene', 'Hamid Hassan', 'Hammad Azam',
#        'Henry K Olonga', 'Ian D R Bradshaw', 'Ian G Butler',
#        'Ian R Redpath', 'Ian W Callen', 'Ijaz Faqih', 'Imran Tahir',
#        'James C Tredwell', 'Jamie O Troughton', 'Jason Patraj',
#        'Javed Qadeer', 'Jeetan S Patel', 'Jeffrey K Moss', 'Jeroen Smits',
#        'Jignesh H Desai', 'Johann D Nel', 'John A Rennie', 'John K Lever',
#        'John M Parker', 'John N Maguire', 'John P R Lamsam',
#        'Joseph R Ratnayeke', 'Joseph V Harris', 'Junaid Siddiqui',
#        'Kalpesh A  Patel', 'Kandage H R K Fernando',
#        'Karunakalage S C de Silva', 'Karuppiahyage R Pushpakumara',
#        'Kaushik N Amalean', 'Keegan O Meth', 'Kemar A J Roach',
#        'Kenneth E D Carroll', 'Kevin J Wright', 'Kevin T Sandher',
#        'Lance J Hamilton', 'Laurie R Williams', 'Laxman Sivaramakrishnan',
#        'Louis J Koen', 'Mahawaduge D K Perera', 'Makhaya Ntini',
#        'Maninder Singh', 'Mannava S K Prasad', 'Mansoor Amjad',
#        'Maqsood Rana', 'Mark H Richardson', 'Mark J Haslam',
#        'Mark W Priest', 'Martin A Suji', 'Matthew J Hoggard',
#        'Maxwell H N Walker', 'Merwyn V Dillon', 'Michael A Holding',
#        'Michael F Malone', 'Mluleki L Nkala', 'Mohamed N Nawaz',
#        'Mohammad Amir', 'Mohammad Q Sheikh', 'Mohammed Sharif',
#        'Mornantau Hayward', 'Morshed Ali Khan', 'Mosharraf Hossain',
#        'Mpumelelo Mbangwa', 'Munaf M Patel', "Murphy L Su'A",
#        'Mushfiqur Rahman', 'Najeeb Aamer', 'Narendra D Hirwani',
#        'Nasir Ahmed', 'Ngonidzashe B Mahwire', 'Nilesh M Kulkarni',
#        'Nitish R Kumar ', 'Nizel Fernandes', 'Norman G Cowans',
#        'Oronde Bascombe', 'Pallemoni Krishnamurthy', 'Patrick I Pocock',
#        'Paul R Adams', 'Pedro T Collins', 'Peter Connell',
#        'Peter M Seelar', 'Peter W E Rawson', 'Pulasthi W Gunaratne',
#        'Qaiser Ali', 'Rafiqul Alam', 'Rahul L Sanghvi', 'Rahul Sharma',
#        'Rana Omer Hussain', 'Rangana Herath', 'Ranganath Vinay Kumar',
#        'Ratnayake A P Nissanka', 'Raymond J Bright', 'Reinhardt Strydom',
#        'Richard L Johnson', 'Richard O Collinge', 'Richard S Gabriel',
#        'Rikki Clarke', 'Robert A Woolmer', 'Robert W Taylor',
#        'Robin D Jackman', 'Rodney J McCurdy', 'Rodney J Trott',
#        'Roger G C E Wijesuriya', 'Roger K Whelan', 'Rohan P Alexander',
#        'Rohan S A Jayasekera', 'Roydon L Hayes', 'Rudra P  Singh Jr',
#        'Russell D M Leverock', 'Ryan  McLaren', 'Saeed Ajmal',
#        'Saeed Azad', 'Safyaan Sharif', 'Sagi L Venkatapathy Raju',
#        'Sajid Ali', 'Sajjad Ahmed', 'Saleem Altaf', 'Salim Jaffer',
#        'Samiur Rahman', 'Sandeep K Gupta', 'Sangarange D Anurasiri',
#        'Sanjay B Bangar', 'Sanjayan Thuraisingam', 'Sanjeev K Sharma',
#        'Sanwar Hossain', 'Sarfraz Ahmed', 'Sarfraz Nawaz', 'Shafiq Ahmed',
#        'Shafiul Islam', 'Shahadat Hossain', 'Shanan L Stewart',
#        'Shaul H U Karnain', 'Shaun F Graf', 'Shaun W Tait',
#        "Shayne B O'Connor", 'Shikhar Dharwan', 'Simon P Jones',
#        'Sohail Butt', 'Sohail Khan', 'Sridharan Jeganathan',
#        'Stefan K W Kelly', 'Stephan J Swanepoel', 'Stephen G Peall',
#        'Stephen J Rixon', 'Steven D Outerbridge', 'Steven T Finn',
#        'Stewart P Heaney', 'Stuart J Roberts', 'Subramaniam Badrinath',
#        'Sudeep Tyagi', 'Syed Maqsood', 'Syed Rasel', 'Sylvester C Joseph',
#        'Taslim Arif', 'Tausif Ahmed', 'Tawanda Mupariwa',
#        'Terrence J Jenner', 'Thudellage C B Fernando', 'Timycen Maruma',
#        'Tirotenda M K Mawoyo', 'Trevor E Jesty', 'Trevor N Madondo',
#        'Trevor R Gripper', 'Tushar Imran', 'Tyson G Gordon',
#        'Ujesh Ranchod', 'Usman Salahuddin', 'Vasbert C Drakes',
#        'Vijay Mehra', 'Vikrant Shetty', 'Vinothen B John', 'Wasim Haider',
#        'William Watson', 'Winston W Davis',
#        'Withanaarchchige C A Ganegama', 'Zahid Hussain', 'Zubin E Surkari',
#        'Zulfiqar Ali', 'Zulquarnain'], dtype=object)

# %%
data['Player'].nunique()
# Out:
# 1936
